# %% [markdown]
# # DS3 SQL Workshop
#
# ### Monday, January 28, 2023
# ### Baraa Zekeria and Ojas Vashishtha

# %% [markdown]
# ## Setup

# %%
# upgrade pip
# !{sys.executable} -m pip install --upgrade pip

# install external libraries
import sys
# !{sys.executable} -m pip install pandas # data manipulation & analysis
# !{sys.executable} -m pip install sqlite3 # SQL

# import libraries
import pandas as pd
import sqlite3

# notebook configurations
pd.options.display.max_colwidth = 1000

import warnings
warnings.filterwarnings("ignore")

print("\n**ALL LIBRARIES IMPORTED SUCCESSFULLY**")
# Out:
# zsh:1: parse error near `-m'
# Requirement already satisfied: pandas in /Users/baraazekeria/opt/anaconda3/lib/python3.8/site-packages (1.2.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/baraazekeria/opt/anaconda3/lib/python3.8/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /Users/baraazekeria/opt/anaconda3/lib/python3.8/site-packages (from pandas) (2021.1)
# Requirement already satisfied: numpy>=1.16.5 in /Users/baraazekeria/opt/anaconda3/lib/python3.8/site-packages (from pandas) (1.20.1)
# Requirement already satisfied: six>=1.5 in /Users/baraazekeria/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# ERROR: Could not find a version that satisfies the requirement sqlite3 (from versions: none)
# ERROR: No matching distribution found for sqlite3
#
# **ALL LIBRARIES IMPORTED SUCCESSFULLY**

# %% [markdown]
# ## Connect to SQLite Database

# %% [markdown]
# ### Step 1: Import Library
# [sqlite3](https://docs.python.org/3/library/sqlite3.html)

# %%
import sqlite3

# %% [markdown]
# ### Step 2: Create a connection

# %%
connection = sqlite3.connect("ds3_key.db")

# %% [markdown]
# ### Step 3: Create a cursor object

# %%
crsr = connection.cursor()

# %% [markdown]
# ### Step 4: Convert pandas DataFrame() to a SQL Table

# %%
independents = pd.read_csv("data/Independents100.csv")
independents = independents.assign(sales = independents["sales"].apply(int))
ratings = pd.read_csv("data/independents_ratings.csv")

# %%
independents.to_sql("independents", con = connection)
ratings.to_sql("ratings", con = connection)

# %% [markdown]
# #### Datasets info
# - ```independents```: 100 highest-grossing independent restaurants in the US
#     - Sorted by ```sales``` in *descending* order
# - ```ratings```: Yelp ratings from March 2021 for restaurants in ```independents```

# %% [markdown]
# ### Step 5: Create queries!

# %%
pd.read_sql('''SELECT * 
            FROM independents''', connection)
# Out:
#     index  rank                           restaurant     sales  avg_check  \
# 0       0     1             Carmine's (Times Square)  39080335         40
# 1       1     2                The Boathouse Orlando  35218364         43
# 2       2     3                     Old Ebbitt Grill  29104017         33
# 3       3     4  LAVO Italian Restaurant & Nightclub  26916180         90
# 4       4     5             Bryant Park Grill & Cafe  26900000         62
# ..    ...   ...                                  ...       ...        ...
# 95     95    96                 George's at the Cove  12194000         80
# 96     96    97                            Le Coucou  12187523         95
# 97     97    98                              Mi Vida  12032014         38
# 98     98    99                               Upland  11965564         52
# 99     99   100               Virgil's Real Barbecue  11391678         27
#
#           city   state  meals_served
# 0     New York    N.Y.      469803.0
# 1     Orlando     Fla.      820819.0
# 2   Washington    D.C.      892830.0
# 3     New York    N.Y.      198500.0
# 4     New York    N.Y.      403000.0
# ..         ...     ...           ...
# 95    La Jolla  Calif.      250000.0
# 96    New York    N.Y.       87070.0
# 97  Washington    D.C.      226226.0
# 98    New York    N.Y.      171825.0
# 99   Las Vegas    Nev.      208276.0
#
# [100 rows x 8 columns]

# %%
pd.read_sql('''SELECT * 
            FROM ratings''', connection)
# Out:
#     index                      restaurant             city  rating
# 0       0           15th Street Fisheries  Fort Lauderdale     3.5
# 1       1                   Abe & Louie's           Boston     4.0
# 2       2                Acme Feed & Seed        Nashville     4.0
# 3       3                      Angus Barn          Raleigh     4.0
# 4       4             Atlanta Fish Market          Atlanta     3.5
# ..    ...                             ...              ...     ...
# 86     86  Top of the World at the STRAT         Las Vegas     4.5
# 87     87                          Upland         New York     4.0
# 88     88          Virgil's Real Barbecue         New York     3.5
# 89     89          Virgil's Real Barbecue        Las Vegas     4.0
# 90     90        Zehnder's of Frankenmuth      Frankenmuth     3.5
#
# [91 rows x 4 columns]

# %% [markdown]
# ## Basic Commands
#
# | Keyword | Description
# | :- | :-
# | **SELECT**|Selects data from a database
# | **AS**| Renames a columns or table with an alias
# | **FROM**| Specifies which table to select or delete data from
# | **WHERE**| Filters a result set to include only records that fulfill a specified condition
# | **JOIN**| Joins tables (right, left, inner, outer, etc.)
# | **GROUP BY**| Groups the result set (used with aggregate functions: ```COUNT```, ```MAX```, ```MIN```, ```SUM```, ```AVG```)
# | **HAVING**| Used instead of ```WHERE``` with aggreagte functions
# | **ORDER BY**| Sorts the result set in ascending or descending order

# %% [markdown]
# ## Ex 1: Write a query to output all of the restaurants in California and New York
#
# |    |   rank | restaurant                                  |    sales |   avg_check | city           | state   |   meals_served |
# |---:|-------:|:--------------------------------------------|---------:|------------:|:---------------|:--------|---------------:|
# |  0 |      1 | Carmine's (Times Square)                    | 39080335 |          40 | New York       | N.Y.    |         469803 |
# |  3 |      4 | LAVO Italian Restaurant & Nightclub         | 26916180 |          90 | New York       | N.Y.    |         198500 |
# |  4 |      5 | Bryant Park Grill & Cafe                    | 26900000 |          62 | New York       | N.Y.    |         403000 |
# |  8 |      9 | Balthazar                                   | 24547800 |          87 | New York       | N.Y.    |         519000 |
# |  9 |     10 | Smith & Wollensky                           | 24501000 |         107 | New York       | N.Y.    |         257364 |
# | ... |     ... | ...                     | ... |          ... | ...       | ...    |         ... |
# | 92 |     93 | Virgil's Real Barbecue                      | 12245998 |          31 | New York       | N.Y.    |         251800 |
# | 94 |     95 | Franciscan Crab Restaurant                  | 12218147 |          59 | San Francisco  | Calif.  |         240000 |
# | 95 |     96 | George's at the Cove                        | 12194000 |          80 | La Jolla       | Calif.  |         250000 |
# | 96 |     97 | Le Coucou                                   | 12187523 |          95 | New York       | N.Y.    |          87070 |
# | 98 |     99 | Upland                                      | 11965564 |          52 | New York       | N.Y.    |         171825 |
#
# 33 rows x 7 columns

# %%
pd_ca_ny = independents[independents["state"].isin(["Calif.", "N.Y."])]
pd_ca_ny
# Out:
#     rank                                   restaurant     sales  avg_check  \
# 0      1                     Carmine's (Times Square)  39080335         40
# 3      4          LAVO Italian Restaurant & Nightclub  26916180         90
# 4      5                     Bryant Park Grill & Cafe  26900000         62
# 8      9                                    Balthazar  24547800         87
# 9     10                            Smith & Wollensky  24501000        107
# 13    14                      Junior's (Times Square)  23640652         23
# 19    20                                     Buddakan  22395577         67
# 30    31                                Quality Meats  18678000        115
# 31    32                                    Del Posto  18625033        194
# 33    34                                Bottega Louie  18521000         36
# 39    40                      Original Joe's Westlake  18159612         35
# 42    43                       Junior's (49th Street)  17834390         22
# 46    47                Harris Ranch Inn & Restaurant  17599468         29
# 47    48                           Sparks Steak House  17519030        100
# 48    49                              Quality Italian  17519000         95
# 50    51                          Tavern on the Green  17212800         76
# 53    54               Beauty & Essex (New York City)  16364050         90
# 54    55                     Grand Central Oyster Bar  16304883         62
# 60    61                             Keens Steakhouse  15629700         97
# 62    63                                   China Live  15106280         54
# 70    71                                  Cliff House  14465847         40
# 71    72                             Castaway Burbank  14407413         60
# 76    77                          Junior's (Brooklyn)  13908292         23
# 78    79                     Paradise Cove Beach Cafe  13654113         39
# 79    80                              BOA Steakhouse   13552485        110
# 80    81                               Original Joe's  13177468         45
# 86    87                                      Scoma's  12713394         65
# 90    91  Park Avenue Summer (Autumn, Winter, Spring)  12498000         84
# 92    93                       Virgil's Real Barbecue  12245998         31
# 94    95                   Franciscan Crab Restaurant  12218147         59
# 95    96                         George's at the Cove  12194000         80
# 96    97                                    Le Coucou  12187523         95
# 98    99                                       Upland  11965564         52
#
#               city   state  meals_served
# 0         New York    N.Y.      469803.0
# 3         New York    N.Y.      198500.0
# 4         New York    N.Y.      403000.0
# 8         New York    N.Y.      519000.0
# 9         New York    N.Y.      257364.0
# 13        New York    N.Y.      914500.0
# 19        New York    N.Y.      221059.0
# 30        New York    N.Y.      165148.0
# 31        New York    N.Y.       95000.0
# 33     Los Angeles  Calif.      322562.0
# 39       Daly City  Calif.      473492.0
# 42        New York    N.Y.      798000.0
# 46        Coalinga  Calif.      611928.0
# 47        New York    N.Y.      198200.0
# 48        New York    N.Y.      177337.0
# 50        New York    N.Y.      250000.0
# 53        New York    N.Y.      187970.0
# 54        New York    N.Y.      296000.0
# 60        New York    N.Y.      168301.0
# 62   San Francisco  Calif.      300000.0
# 70   San Francisco  Calif.      199901.0
# 71         Burbank  Calif.      180320.0
# 76        New York    N.Y.      359000.0
# 78          Malibu  Calif.      312050.0
# 79  West Hollywood  Calif.      123204.0
# 80   San Francisco  Calif.      267533.0
# 86   San Francisco  Calif.      292000.0
# 90        New York    N.Y.      164531.0
# 92        New York    N.Y.      251800.0
# 94   San Francisco  Calif.      240000.0
# 95        La Jolla  Calif.      250000.0
# 96        New York    N.Y.       87070.0
# 98        New York    N.Y.      171825.0

# %%
sql_ca_ny = pd.read_sql('''SELECT * 
                        FROM independents 
                        WHERE state IN ("Calif.", "N.Y.")''', connection)
sql_ca_ny
# Out:
#     index  rank                                   restaurant     sales  \
# 0       0     1                     Carmine's (Times Square)  39080335
# 1       3     4          LAVO Italian Restaurant & Nightclub  26916180
# 2       4     5                     Bryant Park Grill & Cafe  26900000
# 3       8     9                                    Balthazar  24547800
# 4       9    10                            Smith & Wollensky  24501000
# 5      13    14                      Junior's (Times Square)  23640652
# 6      19    20                                     Buddakan  22395577
# 7      30    31                                Quality Meats  18678000
# 8      31    32                                    Del Posto  18625033
# 9      33    34                                Bottega Louie  18521000
# 10     39    40                      Original Joe's Westlake  18159612
# 11     42    43                       Junior's (49th Street)  17834390
# 12     46    47                Harris Ranch Inn & Restaurant  17599468
# 13     47    48                           Sparks Steak House  17519030
# 14     48    49                              Quality Italian  17519000
# 15     50    51                          Tavern on the Green  17212800
# 16     53    54               Beauty & Essex (New York City)  16364050
# 17     54    55                     Grand Central Oyster Bar  16304883
# 18     60    61                             Keens Steakhouse  15629700
# 19     62    63                                   China Live  15106280
# 20     70    71                                  Cliff House  14465847
# 21     71    72                             Castaway Burbank  14407413
# 22     76    77                          Junior's (Brooklyn)  13908292
# 23     78    79                     Paradise Cove Beach Cafe  13654113
# 24     79    80                              BOA Steakhouse   13552485
# 25     80    81                               Original Joe's  13177468
# 26     86    87                                      Scoma's  12713394
# 27     90    91  Park Avenue Summer (Autumn, Winter, Spring)  12498000
# 28     92    93                       Virgil's Real Barbecue  12245998
# 29     94    95                   Franciscan Crab Restaurant  12218147
# 30     95    96                         George's at the Cove  12194000
# 31     96    97                                    Le Coucou  12187523
# 32     98    99                                       Upland  11965564
#
#     avg_check            city   state  meals_served
# 0          40        New York    N.Y.      469803.0
# 1          90        New York    N.Y.      198500.0
# 2          62        New York    N.Y.      403000.0
# 3          87        New York    N.Y.      519000.0
# 4         107        New York    N.Y.      257364.0
# 5          23        New York    N.Y.      914500.0
# 6          67        New York    N.Y.      221059.0
# 7         115        New York    N.Y.      165148.0
# 8         194        New York    N.Y.       95000.0
# 9          36     Los Angeles  Calif.      322562.0
# 10         35       Daly City  Calif.      473492.0
# 11         22        New York    N.Y.      798000.0
# 12         29        Coalinga  Calif.      611928.0
# 13        100        New York    N.Y.      198200.0
# 14         95        New York    N.Y.      177337.0
# 15         76        New York    N.Y.      250000.0
# 16         90        New York    N.Y.      187970.0
# 17         62        New York    N.Y.      296000.0
# 18         97        New York    N.Y.      168301.0
# 19         54   San Francisco  Calif.      300000.0
# 20         40   San Francisco  Calif.      199901.0
# 21         60         Burbank  Calif.      180320.0
# 22         23        New York    N.Y.      359000.0
# 23         39          Malibu  Calif.      312050.0
# 24        110  West Hollywood  Calif.      123204.0
# 25         45   San Francisco  Calif.      267533.0
# 26         65   San Francisco  Calif.      292000.0
# 27         84        New York    N.Y.      164531.0
# 28         31        New York    N.Y.      251800.0
# 29         59   San Francisco  Calif.      240000.0
# 30         80        La Jolla  Calif.      250000.0
# 31         95        New York    N.Y.       87070.0
# 32         52        New York    N.Y.      171825.0

# %% [markdown]
# ## Q1: Write a query to output the name of restaurants in California that has an average check less than 50.
#
# |    | restaurant                    |
# |---:|:------------------------------|
# | 33 | Bottega Louie                 |
# | 39 | Original Joe's Westlake       |
# | 46 | Harris Ranch Inn & Restaurant |
# | 70 | Cliff House                   |
# | 78 | Paradise Cove Beach Cafe      |
# | 80 | Original Joe's                |
#
# 6 rows x 1 column

# %%
pd_ca_50 = independents[(independents["state"] == "Calif.") & (independents["avg_check"] < 50)][["restaurant"]]
pd_ca_50
# Out:
#                        restaurant
# 33                  Bottega Louie
# 39        Original Joe's Westlake
# 46  Harris Ranch Inn & Restaurant
# 70                    Cliff House
# 78       Paradise Cove Beach Cafe
# 80                 Original Joe's

# %%
sql_ca_ny = pd.read_sql('''SELECT restaurant
                        FROM independents 
                        WHERE state = "Calif." AND avg_check < 50''', connection)
sql_ca_ny
# Out:
#                       restaurant
# 0                  Bottega Louie
# 1        Original Joe's Westlake
# 2  Harris Ranch Inn & Restaurant
# 3                    Cliff House
# 4       Paradise Cove Beach Cafe
# 5                 Original Joe's

# %% [markdown]
# ## Q2: Write a query to merge restaurants and rankings. Assign to ```sql_merge```.
#
# |    |   rank | restaurant                                  |    sales |   avg_check | city            | state   |   meals_served |   rating |
# |---:|-------:|:--------------------------------------------|---------:|------------:|:----------------|:--------|---------------:|---------:|
# |  0 |      1 | Carmine's (Times Square)                    | 39080335 |          40 | New York        | N.Y.    |         469803 |      4   |
# |  1 |      2 | The Boathouse Orlando                       | 35218364 |          43 | Orlando         | Fla.    |         820819 |      4   |
# |  2 |      4 | LAVO Italian Restaurant & Nightclub         | 26916180 |          90 | New York        | N.Y.    |         198500 |      2.5 |
# |  3 |      5 | Bryant Park Grill & Cafe                    | 26900000 |          62 | New York        | N.Y.    |         403000 |      3.5 |
# |  4 |      6 | Gibsons Bar & Steakhouse                    | 25409952 |          80 | Chicago         | Ill.    |         348567 |      4   |
# |  ... |      ... | ...              | ... |         ... | ...       | ...    |         ... |      ... |
# | 86 |     95 | Franciscan Crab Restaurant                  | 12218147 |          59 | San Francisco   | Calif.  |         240000 |      3.5 |
# | 87 |     96 | George's at the Cove                        | 12194000 |          80 | La Jolla        | Calif.  |         250000 |      4   |
# | 88 |     97 | Le Coucou                                   | 12187523 |          95 | New York        | N.Y.    |          87070 |      4   |
# | 89 |     99 | Upland                                      | 11965564 |          52 | New York        | N.Y.    |         171825 |      4   |
# | 90 |    100 | Virgil's Real Barbecue                      | 11391678 |          27 | Las Vegas       | Nev.    |         208276 |      4   |
#
# 91 rows x 8 columns

# %%
sql_merge = pd.read_sql('''SELECT independents.rank, independents.restaurant, independents.sales, 
                        independents.avg_check, independents.city, independents.state,
                        independents.meals_served, ratings.rating
                        
                        FROM independents 
                        
                        INNER JOIN ratings ON independents.restaurant  = ratings.restaurant 
                                                          AND 
                                           independents.city  = ratings.city;''', connection)
sql_merge
# Out:
#     rank                           restaurant     sales  avg_check  \
# 0      1             Carmine's (Times Square)  39080335         40
# 1      2                The Boathouse Orlando  35218364         43
# 2      4  LAVO Italian Restaurant & Nightclub  26916180         90
# 3      5             Bryant Park Grill & Cafe  26900000         62
# 4      6             Gibsons Bar & Steakhouse  25409952         80
# ..   ...                                  ...       ...        ...
# 86    95           Franciscan Crab Restaurant  12218147         59
# 87    96                 George's at the Cove  12194000         80
# 88    97                            Le Coucou  12187523         95
# 89    99                               Upland  11965564         52
# 90   100               Virgil's Real Barbecue  11391678         27
#
#              city   state  meals_served  rating
# 0        New York    N.Y.      469803.0     4.0
# 1        Orlando     Fla.      820819.0     4.0
# 2        New York    N.Y.      198500.0     2.5
# 3        New York    N.Y.      403000.0     3.5
# 4         Chicago    Ill.      348567.0     4.0
# ..            ...     ...           ...     ...
# 86  San Francisco  Calif.      240000.0     3.5
# 87       La Jolla  Calif.      250000.0     4.0
# 88       New York    N.Y.       87070.0     4.0
# 89       New York    N.Y.      171825.0     4.0
# 90      Las Vegas    Nev.      208276.0     4.0
#
# [91 rows x 8 columns]

# %% [markdown]
# Let's save ```sql_merge``` as a SQL table for easy access.
#
# If you accidently delete the code below, please run the following in a new cell to save your table within ```ds3_key.db```:
#
# ```py
# sql_merge.to_sql("sql_merge", con = connection)
# ```

# %%
sql_merge.to_sql("sql_merge", con = connection)

# %% [markdown]
# ## Q3: Write a query that finds the average check per state. Then, for the most expensive state, find the most expensive restaurant. Is that also the highest rated restaurant for that state? Output all the columns for this question.

# %%
sql_avg = pd.read_sql('''SELECT AVG(avg_check) as total_avg_checks, state
                        
                        FROM  sql_merge
                        GROUP BY state
                        ORDER BY total_avg_checks DESC ''', connection)
sql_avg
# Out:
#     total_avg_checks   state
# 0         106.000000   Mass.
# 1          97.454545    Nev.
# 2          83.000000    Ore.
# 3          82.500000    Ind.
# 4          82.444444    Ill.
# 5          81.500000     Ga.
# 6          76.761905    N.Y.
# 7          75.000000    N.C.
# 8          72.666667    Fla.
# 9          69.000000   Fla.
# 10         54.333333  Calif.
# 11         41.000000    N.J.
# 12         38.000000     Va.
# 13         37.000000   Colo.
# 14         36.000000   Texas
# 15         35.000000     Pa.
# 16         30.500000   Tenn.
# 17         18.000000   Mich.

# %%
sql_fla = pd.read_sql('''SELECT *
                        
                        FROM  sql_merge
                        WHERE state = "Fla."
                        ORDER BY avg_check''', connection)
sql_fla
# Out:
#    index  rank             restaurant     sales  avg_check            city  \
# 0      1     2  The Boathouse Orlando  35218364         43        Orlando
# 1     53    59         The Rustic Inn  15700000         43  Ft. Lauderdale
# 2     23    27             Paddlefish  19829500         48        Orlando
# 3     34    39                 Makoto  18216906         54     Bal Harbour
# 4     29    33    Shooters Waterfront  18601433         57  Ft. Lauderdale
# 5     60    66                   Swan  15000000         78           Miami
# 6     15    19                 Komodo  22500000         98           Miami
# 7     47    53          Rusty Pelican  16981741         98           Miami
# 8     10    12              Prime 112  23800000        135     Miami Beach
#
#   state  meals_served  rating
# 0  Fla.      820819.0     4.0
# 1  Fla.      371000.0     4.0
# 2  Fla.      417500.0     4.0
# 3  Fla.      256830.0     4.5
# 4  Fla.      409752.0     4.0
# 5  Fla.      225000.0     3.5
# 6  Fla.      265000.0     4.0
# 7  Fla.      182000.0     3.5
# 8  Fla.      206000.0     3.5

# %%
sql_most_exp_fla = pd.read_sql('''SELECT *
                        
                        FROM  sql_merge
                        WHERE state = "Fla."
                        ORDER BY avg_check desc
                        LIMIT 1''', connection)
sql_most_exp_fla
# Out:
#    index  rank restaurant     sales  avg_check         city state  \
# 0     10    12  Prime 112  23800000        135  Miami Beach  Fla.
#
#    meals_served  rating
# 0      206000.0     3.5

# %%
sql_most_rat_fla = pd.read_sql('''SELECT *
                        
                        FROM  sql_merge
                        WHERE state = "Fla."
                        ORDER BY rating desc
                        LIMIT 1''', connection)
sql_most_rat_fla
# Out:
#    index  rank restaurant     sales  avg_check         city state  \
# 0     34    39     Makoto  18216906         54  Bal Harbour  Fla.
#
#    meals_served  rating
# 0      256830.0     4.5

# %% [markdown]
# ## Q4: Write your own query! Use the data given and the commands to find useful insights/something interesting in the data. Each group will share their findings!

# %%
...
# Out:
# Ellipsis
